# %%
import os
import io
from scipy import interpolate, stats
import RockPy3
RockPy3.core.utils.setLatex()
# %pylab inline
# Out:
# IMPLEMENTED MEASUREMENT TYPES     : 	FTYPES
# ---------------------------------------------------------------------------
# 	acquisition               : 	jr6, sushibar
# 	afdemagnetization         : 	cryomag, jr6, sushibar
# 	backfield                 : 	vsm, vftb
# 	bedding                   : 	generic
# 	demagnetization           : 	cryomag, jr6, sushibar
# 	diameter                  : 	generic
# 	height                    : 	generic
# 	hysteresis                : 	vsm, vftb, mpms
# 	irm_acquisition           : 	jr6, vsm, sushibar
# 	length                    : 	generic
# 	locationgeo               : 	generic
# 	mass                      : 	generic
# 	orientationgeo            : 	generic
# 	paleointensity            :
# 	parameter                 :
# 	parm_acquisition          : 	jr6, sushibar
# 	thermaldemagnetization    : 	cryomag, jr6, sushibar
# 	thermocurve               : 	vsm, vftb, mpms
# 	volume                    :
# Populating the interactive namespace from numpy and matplotlib

# %%
folder = '/Users/Mike/Dropbox/PHD/006_HT-ARM-AF/Dunlop_Bina_datapoints'
files = [i for i in os.listdir(folder) if i.endswith('.dat')]

# %%
data = {}
for f in files:
    sname = int(f.split('_')[0][:-1])/10
    temp = float(f.split('_')[1][:3])
    data.setdefault(sname, {})
    s = open(os.path.join(folder, f)).read().replace(',','.')
    data[sname][temp] = np.loadtxt(io.StringIO(s))

# %%
print(data.keys())
# Out:
# dict_keys([76.0, 220.0, 100.0, 37.0])

# %%
for s in sorted(data):
    temps = sorted(data[s].keys())
    for t, v in sorted(data[s].items()):
        plot(v[:,0]/10, v[:,1], '.-', label='{:4.0f} K'.format(t), color = RockPy3.colorscheme[temps.index(t)])
    title('{} nm'.format(s))
    xlim(0,55)
    ylim(0,1)
    xlabel('AF field [mT]')
    ylabel('normalized moment')
    legend(loc='best', numpoints=1, frameon=False, handlelength=1)
    savefig(folder+'/Dunlop1977({})_data.pdf'.format(s))
    show()

# %%
def calculate_sample(sname='760A'):
    temps = data[sname].keys()
    m0 = data[sname][min(temps)]
    vars = m0[:,1]
    out = {}
    for t, m in data[sname].items():
        if not t == min(temps):

            f = interpolate.interp1d(m[:,1], m[:,0], bounds_error=False)
            m = np.c_[f(vars), vars]
        out[t] = m
    return out

# %%
slopes = {}
for s in data:
    slopes.setdefault(s, [])
    newdata = calculate_sample(s)
    temps = sorted(newdata.keys())
    mint = min(temps)
    for t in sorted(newdata):
        xy = np.c_[newdata[mint][:,0]/10, newdata[t][:,0]/10]
        xy = xy[~np.isnan(xy).any(axis=1)]
        line, = plot(xy[:,0], xy[:,1], '.', color = RockPy3.colorscheme[temps.index(t)], 
             label = '${}^\circ C$'.format(int(t)))
        slope, intercept, r_value, p_value, std_err = stats.linregress(xy[:,0], xy[:,1])
        plot((0,50), intercept+slope*np.array((0,50)), color = line.get_color())
        if isnan(slope):
            print(s,t)
        slopes[s].append([t,slope, intercept, r_value, p_value, std_err ])
    xlabel('$B_n(T_0)$ [mT]')
    ylabel('$B_n(T_n)$ [mT]')
    xlim(0,50)
    ylim(0,50)
    legend(loc='best')
    title('{} nm'.format(s))
    savefig(folder+'/Dunlop1977({})_Bn(T_0)_vs_Bn(T_i).pdf'.format(s))
    show()
    slopes[s] = np.array(slopes[s])

# %%
# format : sname, temp, slope, 1/slope, 1/slope/v
our_data = array([[['1125', '300', '0.590222928602', '1.69427508072',
         '0.0056475836024']],

       [['1125', '500', '0.300124299576', '3.33195279893',
         '0.00666390559787']],

       [['1524', '300', '0.428538557298', '2.33351231288',
         '0.00777837437627']],

       [['1524', '500', '0.37622590388', '2.65797753341',
         '0.00531595506682']],

       [['525', '300', '0.560707969545', '1.78345958024',
         '0.00594486526745']],

       [['525', '500', '0.222095150957', '4.50257466537',
         '0.00900514933074']],

       [['IXD', '300', '0.485314672156', '2.06051878786',
         '0.00686839595952']],

       [['IXD', '500', '0.129851999359', '7.70107510811', '0.0154021502162']],

       [['Va', '300', '0.494523844438', '2.02214718511', '0.00674049061703']],

       [['Va', '500', '0.151276880646', '6.61039542679', '0.0132207908536']],

       [['Vb', '300', '0.512144615302', '1.95257349218', '0.00650857830726']],

       [['Vb', '500', '0.13251610828', '7.54625239887', '0.0150925047977']]], 
      dtype='<U16')

# %%
for i,s in enumerate(sorted(slopes)):
    plot(slopes[s][:,0], slopes[s][:,1], '.-', label='{} nm'.format(s), color=RockPy3.colorscheme[i])
    legend(loc='best')
    xlabel('Temperature')
    ylabel('slope')

for d in our_data:
    
savefig(folder+'/Dunlop1977_slope_vs_T.pdf')
